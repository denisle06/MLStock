# %%
# %pip install -U massive
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting openpyxl
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 330.3 kB/s eta 0:00:01
#    ------- ------------------------------- 51.2/250.9 kB 327.7 kB/s eta 0:00:01
#    -------------- ------------------------ 92.2/250.9 kB 585.1 kB/s eta 0:00:01
#    ----------------- -------------------- 112.6/250.9 kB 469.7 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/250.9 kB 450.6 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/250.9 kB 622.7 kB/s eta 0:00:01
#    ---------------------------------- --- 225.3/250.9 kB 626.9 kB/s eta 0:00:01
#    -------------------------------------- 250.9/250.9 kB 617.1 kB/s eta 0:00:00
# ...

# %%
from massive import RESTClient
import pandas as pd

client = RESTClient(api_key="vXhZQ59GQnVopnZfKasWB5NXv9pqD1mw")

ticker = "AAPL"

# List Aggregates (Bars)
aggs = []
for a in client.list_aggs(ticker=ticker, multiplier=1, timespan="minute", from_="2025-01-01", to="2025-06-13", limit=50000):
    aggs.append(a)
    
# Convert to DataFrame
df = pd.DataFrame([a.__dict__ for a in aggs])

print(df.head())

# Save to xlsx
df.to_excel("AAPL_aggs.xlsx", index=False)
print("Saved to AAPL_aggs.xlsx")
# Out:
#      open    high     low   close  volume      vwap      timestamp  \
# 0  251.36  251.36  250.60  250.60   834.0  251.2067  1735808400000
# 1  251.42  251.42  251.26  251.26  1175.0  251.3199  1735808460000
# 2  251.32  251.32  251.31  251.31   847.0  251.3152  1735808520000
# 3  251.21  251.21  251.09  251.09  1692.0  251.1570  1735808580000
# 4  251.02  251.13  251.02  251.13   633.0  251.0582  1735808640000
#
#    transactions   otc
# 0            82  None
# 1            47  None
# 2            88  None
# 3            68  None
# 4            48  None
# Saved to AAPL_aggs.xlsx
